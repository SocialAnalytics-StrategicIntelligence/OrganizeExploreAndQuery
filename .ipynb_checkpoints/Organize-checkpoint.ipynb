# %% [markdown]
# <img src="https://i.imgur.com/6U6q5jQ.png"/>
#
# # Data Organization
#
#
# Let me get the data on dengue from [Peru](https://www.datosabiertos.gob.pe/dataset/vigilancia-epidemiol%C3%B3gica-de-dengue):

# %%
import pandas as pd
linkData="https://github.com/SocialAnalytics-StrategicIntelligence/OrganizeExploreAndQuery/raw/main/dataFiles/datos_abiertos_vigilancia_dengue_ok.csv"
dengue = pd.read_csv(linkData,encoding='utf-8', engine='python')
dengue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501692 entries, 0 to 501691
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   departamento  501692 non-null  object
#  1   provincia     501692 non-null  object
#  2   distrito      501692 non-null  object
#  3   localidad     400753 non-null  object
#  4   enfermedad    501692 non-null  object
#  5   ano           501692 non-null  int64
#  6   semana        501692 non-null  int64
#  7   diagnostic    501692 non-null  object
#  8   diresa        501669 non-null  float64
#  9   ubigeo        501692 non-null  int64
#  10  localcod      407822 non-null  object
#  11  edad          501692 non-null  int64
#  12  tipo_edad     501692 non-null  object
#  13  sexo          501692 non-null  object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 53.6+ MB

# %%
dengue.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#                 ano        semana        diresa        ubigeo            edad
# count  501692.00000  501692.00000  501669.00000  501692.00000    501692.00000
# mean     2014.77260      22.00057      22.06243  167285.48278       268.97688
# std         6.14420      14.76501       9.72385   63785.83505    117745.13157
# min      2000.00000       1.00000       2.00000   10101.00000         0.00000
# 25%      2011.00000      11.00000      16.00000  130201.00000        15.00000
# 50%      2016.00000      18.00000      22.00000  170101.00000        26.00000
# 75%      2020.00000      32.00000      31.00000  200601.00000        41.00000
# max      2022.00000      53.00000      99.00000  999999.00000  71963641.00000

# %%
import seaborn as sns

sns.boxplot(x=dengue["edad"],log_scale=(True,None))
# Out:
# <Axes: xlabel='edad'>

# %%
dengue[dengue.edad>110]
# Out:
#        departamento      provincia   distrito           localidad  \
# 264053        PIURA          PIURA   CASTILLA     URB. MIRAFLORES
# 269208        PIURA          PIURA   LA ARENA  BARRIO 13 DE ABRIL
# 272873        PIURA          PIURA   CATACAOS            LA LEGUA
# 278721        PIURA          PIURA      PIURA               PIURA
# 278933        PIURA          PIURA   CASTILLA            CASTILLA
# 284506        PIURA          PIURA      PIURA                  \N
# 288598        PIURA          PIURA  CURA MORI           CUCUNGARA
# 288660        PIURA          PIURA  CURA MORI           CUCUNGARA
# 289614        PIURA          PIURA  CURA MORI           CUCUNGARA
# 297904        PIURA          PIURA  CURA MORI           CUCUNGARA
# 323904       TUMBES         TUMBES    LA CRUZ             LA CRUZ
# 464726        CUSCO  LA CONVENCION    PICHARI             PICHARI
#
#                           enfermedad   ano  semana diagnostic  diresa  ubigeo  \
# 264053  DENGUE SIN SEÑALES DE ALARMA  2017      13      A97.0    32.0  200104
# 269208  DENGUE SIN SEÑALES DE ALARMA  2017      16      A97.0    32.0  200109
# 272873  DENGUE SIN SEÑALES DE ALARMA  2017      17      A97.0    32.0  200105
# 278721  DENGUE SIN SEÑALES DE ALARMA  2017      17      A97.0    32.0  200101
# 278933  DENGUE CON SEÑALES DE ALARMA  2017      17      A97.1    32.0  200104
# 284506  DENGUE CON SEÑALES DE ALARMA  2017      18      A97.1    32.0  200101
# 288598  DENGUE CON SEÑALES DE ALARMA  2017      20      A97.1    32.0  200107
# 288660  DENGUE SIN SEÑALES DE ALARMA  2017      20      A97.0    32.0  200107
# 289614  DENGUE SIN SEÑALES DE ALARMA  2017      20      A97.0    32.0  200107
# 297904  DENGUE SIN SEÑALES DE ALARMA  2017      19      A97.0    32.0  200107
# 323904  DENGUE SIN SEÑALES DE ALARMA  2017      44      A97.0    24.0  240103
# 464726  DENGUE SIN SEÑALES DE ALARMA  2022      16      A97.0     8.0   80910
#
#           localcod      edad tipo_edad sexo
# 264053  2001040028       814         A    F
# 269208  2001090034   2846395         A    M
# 272873  2001050027   2692587         A    M
# 278721  2001010001       330         A    M
# 278933  2001040001      6161         A    M
# 284506  2001010047      3767         A    F
# 288598  2001070001  71963641         A    M
# 288660  2001070001  41964604         A    F
# 289614  2001070001    419454         A    M
# 297904  2001070001    249906         A    M
# 323904  2401030005    228718         A    M
# 464726   809100001     35109         A    F

# %%
dengue=dengue[dengue.edad<=110]

# %% [markdown]
# Let me select a subset of columns:

# %%
toSelect=['departamento', 'provincia', 'distrito','ano', 'semana', 'sexo','edad','enfermedad']
dengueSub=dengue[toSelect]
dengueSub.head()
# Out:
#   departamento      provincia                distrito   ano  semana sexo  \
# 0      HUANUCO  LEONCIO PRADO                 LUYANDO  2000      47    M
# 1      HUANUCO  LEONCIO PRADO                 LUYANDO  2000      40    F
# 2      HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO  2000      48    F
# 3      HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO  2000      37    F
# 4      HUANUCO  LEONCIO PRADO   MARIANO DAMASO BERAUN  2000      42    M
#
#    edad                    enfermedad
# 0     9  DENGUE SIN SEÑALES DE ALARMA
# 1    18  DENGUE SIN SEÑALES DE ALARMA
# 2    32  DENGUE SIN SEÑALES DE ALARMA
# 3    40  DENGUE SIN SEÑALES DE ALARMA
# 4    16  DENGUE SIN SEÑALES DE ALARMA

# %% [markdown]
# As we know there were issues with text, let's check department values:

# %%
dengueSub.departamento.value_counts()
# Out:
# departamento
# PIURA            126400
# LORETO            92496
# UCAYALI           43707
# MADRE DE DIOS     30562
# TUMBES            27313
# SAN MARTIN        26759
# LA LIBERTAD       24377
# ICA               21324
# CAJAMARCA         19409
# JUNIN             19199
# LAMBAYEQUE        15618
# AMAZONAS          12017
# CUSCO             10475
# HUANUCO            9046
# AYACUCHO           8889
# ANCASH             7214
# LIMA               4255
# PASCO              1963
# \N                  444
# PUNO                179
# CALLAO               26
# AREQUIPA              7
# MOQUEGUA              1
# Name: count, dtype: int64

# %%
dengueSub[dengueSub.departamento.str.contains('\\N',regex=False)]
# Out:
#        departamento provincia distrito   ano  semana sexo  edad  \
# 79131            \N        \N       \N  2009       1    F    10
# 79656            \N        \N       \N  2009       7    M    46
# 80500            \N        \N       \N  2009      26    F    42
# 84253            \N        \N       \N  2009      28    M    30
# 85102            \N        \N       \N  2009       4    F    19
# ...             ...       ...      ...   ...     ...  ...   ...
# 480825           \N        \N       \N  2022      23    F    73
# 486719           \N        \N       \N  2022      33    F    17
# 487630           \N        \N       \N  2022      34    M    54
# 491395           \N        \N       \N  2022      43    F    56
# 493020           \N        \N       \N  2022      32    F    20
#
#                           enfermedad
# 79131   DENGUE SIN SEÑALES DE ALARMA
# 79656   DENGUE SIN SEÑALES DE ALARMA
# 80500   DENGUE SIN SEÑALES DE ALARMA
# 84253   DENGUE SIN SEÑALES DE ALARMA
# 85102   DENGUE SIN SEÑALES DE ALARMA
# ...                              ...
# 480825  DENGUE SIN SEÑALES DE ALARMA
# 486719  DENGUE SIN SEÑALES DE ALARMA
# 487630  DENGUE SIN SEÑALES DE ALARMA
# 491395  DENGUE SIN SEÑALES DE ALARMA
# 493020  DENGUE SIN SEÑALES DE ALARMA
#
# [444 rows x 8 columns]

# %%
dengueSub[dengueSub.distrito.str.contains('\\N',regex=False)]
# Out:
#        departamento provincia distrito   ano  semana sexo  edad  \
# 79131            \N        \N       \N  2009       1    F    10
# 79656            \N        \N       \N  2009       7    M    46
# 80500            \N        \N       \N  2009      26    F    42
# 84253            \N        \N       \N  2009      28    M    30
# 85102            \N        \N       \N  2009       4    F    19
# ...             ...       ...      ...   ...     ...  ...   ...
# 480825           \N        \N       \N  2022      23    F    73
# 486719           \N        \N       \N  2022      33    F    17
# 487630           \N        \N       \N  2022      34    M    54
# 491395           \N        \N       \N  2022      43    F    56
# 493020           \N        \N       \N  2022      32    F    20
#
#                           enfermedad
# 79131   DENGUE SIN SEÑALES DE ALARMA
# 79656   DENGUE SIN SEÑALES DE ALARMA
# 80500   DENGUE SIN SEÑALES DE ALARMA
# 84253   DENGUE SIN SEÑALES DE ALARMA
# 85102   DENGUE SIN SEÑALES DE ALARMA
# ...                              ...
# 480825  DENGUE SIN SEÑALES DE ALARMA
# 486719  DENGUE SIN SEÑALES DE ALARMA
# 487630  DENGUE SIN SEÑALES DE ALARMA
# 491395  DENGUE SIN SEÑALES DE ALARMA
# 493020  DENGUE SIN SEÑALES DE ALARMA
#
# [444 rows x 8 columns]

# %% [markdown]
# Now, we keep the complete data:

# %%
# Let's replace that cell value in all the data frame:  
dengueSub.replace('\\N',None,regex=False,inplace=True)
# dropping
dengueSub.dropna(how='any',inplace=True,ignore_index=True)
# Out:
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_69608/3813897578.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dengueSub.replace('\\N',None,regex=False,inplace=True)
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_69608/3813897578.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dengueSub.dropna(how='any',inplace=True,ignore_index=True)

# %%
dengueSub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501236 entries, 0 to 501235
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   departamento  501236 non-null  object
#  1   provincia     501236 non-null  object
#  2   distrito      501236 non-null  object
#  3   ano           501236 non-null  int64
#  4   semana        501236 non-null  int64
#  5   sexo          501236 non-null  object
#  6   edad          501236 non-null  int64
#  7   enfermedad    501236 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 30.6+ MB

# %% [markdown]
# The data is about people, but since there is no identifier for a person, it is possible that rows are repeated:

# %%
dengueSub[dengueSub.duplicated(keep=False)].sort_values(by=['distrito','semana','sexo'])
# Out:
#        departamento              provincia      distrito   ano  semana sexo  \
# 225311   SAN MARTIN              EL DORADO   AGUA BLANCA  2014       9    F
# 225312   SAN MARTIN              EL DORADO   AGUA BLANCA  2014       9    F
# 98379        TUMBES              ZARUMILLA  AGUAS VERDES  2010       6    M
# 98382        TUMBES              ZARUMILLA  AGUAS VERDES  2010       6    M
# 13688        TUMBES              ZARUMILLA  AGUAS VERDES  2001       7    F
# ...             ...                    ...           ...   ...     ...  ...
# 226657       TUMBES  CONTRALMIRANTE VILLAR      ZORRITOS  2014      51    M
# 437124       TUMBES  CONTRALMIRANTE VILLAR      ZORRITOS  2021      52    F
# 437129       TUMBES  CONTRALMIRANTE VILLAR      ZORRITOS  2021      52    F
# 38336        TUMBES  CONTRALMIRANTE VILLAR      ZORRITOS  2003      53    M
# 38343        TUMBES  CONTRALMIRANTE VILLAR      ZORRITOS  2003      53    M
#
#         edad                    enfermedad
# 225311    21  DENGUE SIN SEÑALES DE ALARMA
# 225312    21  DENGUE SIN SEÑALES DE ALARMA
# 98379     25  DENGUE SIN SEÑALES DE ALARMA
# 98382     25  DENGUE SIN SEÑALES DE ALARMA
# 13688     54  DENGUE SIN SEÑALES DE ALARMA
# ...      ...                           ...
# 226657    42  DENGUE CON SEÑALES DE ALARMA
# 437124     1  DENGUE SIN SEÑALES DE ALARMA
# 437129     1  DENGUE SIN SEÑALES DE ALARMA
# 38336     22  DENGUE SIN SEÑALES DE ALARMA
# 38343     22  DENGUE SIN SEÑALES DE ALARMA
#
# [161091 rows x 8 columns]

# %% [markdown]
# To ease the count, we could add a column of ones:

# %%
dengueSub=dengueSub.assign(case=1)
dengueSub.head()
# Out:
#   departamento      provincia                distrito   ano  semana sexo  \
# 0      HUANUCO  LEONCIO PRADO                 LUYANDO  2000      47    M
# 1      HUANUCO  LEONCIO PRADO                 LUYANDO  2000      40    F
# 2      HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO  2000      48    F
# 3      HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO  2000      37    F
# 4      HUANUCO  LEONCIO PRADO   MARIANO DAMASO BERAUN  2000      42    M
#
#    edad                    enfermedad  case
# 0     9  DENGUE SIN SEÑALES DE ALARMA     1
# 1    18  DENGUE SIN SEÑALES DE ALARMA     1
# 2    32  DENGUE SIN SEÑALES DE ALARMA     1
# 3    40  DENGUE SIN SEÑALES DE ALARMA     1
# 4    16  DENGUE SIN SEÑALES DE ALARMA     1

# %%
dengueSub.enfermedad.value_counts()
# Out:
# enfermedad
# DENGUE SIN SEÑALES DE ALARMA    443996
# DENGUE CON SEÑALES DE ALARMA     54981
# DENGUE GRAVE                      2259
# Name: count, dtype: int64

# %%
dengueSub['enfermedad']=dengueSub.enfermedad.str.replace("DENGUE ","")
dengueSub['enfermedad']=dengueSub.enfermedad.str.replace("\s","_",regex=True)
dengueSub['enfermedad']
# Out:
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_69608/4260196624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dengueSub['enfermedad']=dengueSub.enfermedad.str.replace("DENGUE ","")
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_69608/4260196624.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dengueSub['enfermedad']=dengueSub.enfermedad.str.replace("\s","_",regex=True)
# 0         SIN_SEÑALES_DE_ALARMA
# 1         SIN_SEÑALES_DE_ALARMA
# 2         SIN_SEÑALES_DE_ALARMA
# 3         SIN_SEÑALES_DE_ALARMA
# 4         SIN_SEÑALES_DE_ALARMA
#                   ...
# 501231    SIN_SEÑALES_DE_ALARMA
# 501232    SIN_SEÑALES_DE_ALARMA
# 501233    SIN_SEÑALES_DE_ALARMA
# 501234    SIN_SEÑALES_DE_ALARMA
# 501235    SIN_SEÑALES_DE_ALARMA
# Name: enfermedad, Length: 501236, dtype: object

# %%
dengueSub['year']=pd.to_datetime(dengue.ano,format='%Y')
dengueSub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501236 entries, 0 to 501235
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   departamento  501236 non-null  object
#  1   provincia     501236 non-null  object
#  2   distrito      501236 non-null  object
#  3   ano           501236 non-null  int64
#  4   semana        501236 non-null  int64
#  5   sexo          501236 non-null  object
#  6   edad          501236 non-null  int64
#  7   enfermedad    501236 non-null  object
#  8   year          501224 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 34.4+ MB
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_69608/2731343384.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dengueSub['year']=pd.to_datetime(dengue.ano,format='%Y')

# %%
dengueSub['year']
# Out:
# 0        2000-01-01
# 1        2000-01-01
# 2        2000-01-01
# 3        2000-01-01
# 4        2000-01-01
#             ...
# 501231   2022-01-01
# 501232   2022-01-01
# 501233   2022-01-01
# 501234   2022-01-01
# 501235   2022-01-01
# Name: year, Length: 501236, dtype: datetime64[ns]

# %%
# turn intergers into ordinal level

# create the data type info
from pandas.api.types import CategoricalDtype
currentLevels=['SIN_SEÑALES_DE_ALARMA','CON_SEÑALES_DE_ALARMA','GRAVE']
statusDengueOrdinal = CategoricalDtype(categories=currentLevels, ordered=True)

#one column
dengueSub['enfermedad']=dengueSub.enfermedad.astype(statusDengueOrdinal)
dengueSub['enfermedad']
# Out:
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_69608/1028059817.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dengueSub['enfermedad']=dengueSub.enfermedad.astype(statusDengueOrdinal)
# 0         SIN_SEÑALES_DE_ALARMA
# 1         SIN_SEÑALES_DE_ALARMA
# 2         SIN_SEÑALES_DE_ALARMA
# 3         SIN_SEÑALES_DE_ALARMA
# 4         SIN_SEÑALES_DE_ALARMA
#                   ...
# 501231    SIN_SEÑALES_DE_ALARMA
# 501232    SIN_SEÑALES_DE_ALARMA
# 501233    SIN_SEÑALES_DE_ALARMA
# 501234    SIN_SEÑALES_DE_ALARMA
# 501235    SIN_SEÑALES_DE_ALARMA
# Name: enfermedad, Length: 501236, dtype: category
# Categories (3, object): ['SIN_SEÑALES_DE_ALARMA' < 'CON_SEÑALES_DE_ALARMA' < 'GRAVE']

# %%
dengueSub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501236 entries, 0 to 501235
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   departamento  501236 non-null  object
#  1   provincia     501236 non-null  object
#  2   distrito      501236 non-null  object
#  3   ano           501236 non-null  int64
#  4   semana        501236 non-null  int64
#  5   sexo          501236 non-null  object
#  6   edad          501236 non-null  int64
#  7   enfermedad    501236 non-null  category
#  8   year          501224 non-null  datetime64[ns]
# dtypes: category(1), datetime64[ns](1), int64(3), object(4)
# memory usage: 31.1+ MB

# %%
dengueSub.enfermedad
# Out:
# 0         SIN_SEÑALES_DE_ALARMA
# 1         SIN_SEÑALES_DE_ALARMA
# 2         SIN_SEÑALES_DE_ALARMA
# 3         SIN_SEÑALES_DE_ALARMA
# 4         SIN_SEÑALES_DE_ALARMA
#                   ...
# 501231    SIN_SEÑALES_DE_ALARMA
# 501232    SIN_SEÑALES_DE_ALARMA
# 501233    SIN_SEÑALES_DE_ALARMA
# 501234    SIN_SEÑALES_DE_ALARMA
# 501235    SIN_SEÑALES_DE_ALARMA
# Name: enfermedad, Length: 501236, dtype: category
# Categories (3, object): ['SIN_SEÑALES_DE_ALARMA' < 'CON_SEÑALES_DE_ALARMA' < 'GRAVE']

# %%
#currentLevels
newLevels=['SIN_SEÑALES','ALARMA','GRAVE']
{a:b for a,b in zip(currentLevels,newLevels)}
# Out:
# {'SIN_SEÑALES_DE_ALARMA': 'SIN_SEÑALES',
#  'CON_SEÑALES_DE_ALARMA': 'ALARMA',
#  'GRAVE': 'GRAVE'}

# %%
NewOrdinalLevels={a:b for a,b in zip(currentLevels,newLevels)}

dengueSub['enfermedad']=dengueSub.enfermedad.cat.rename_categories(NewOrdinalLevels)
# Out:
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_69608/719479981.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dengueSub['enfermedad']=dengueSub.enfermedad.cat.rename_categories(NewOrdinalLevels)

# %%
dengueSub['enfermedad'].value_counts()
# Out:
# enfermedad
# SIN_SEÑALES    443996
# ALARMA          54981
# GRAVE            2259
# Name: count, dtype: int64

# %%
dengueSub
# Out:
#        departamento      provincia                distrito   ano  semana sexo  \
# 0           HUANUCO  LEONCIO PRADO                 LUYANDO  2000      47    M
# 1           HUANUCO  LEONCIO PRADO                 LUYANDO  2000      40    F
# 2           HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO  2000      48    F
# 3           HUANUCO  LEONCIO PRADO  JOSE CRESPO Y CASTILLO  2000      37    F
# 4           HUANUCO  LEONCIO PRADO   MARIANO DAMASO BERAUN  2000      42    M
# ...             ...            ...                     ...   ...     ...  ...
# 501231   SAN MARTIN     SAN MARTIN                TARAPOTO  2022      13    M
# 501232        PIURA        SECHURA                 SECHURA  2022      13    F
# 501233        PIURA          PIURA                LA UNION  2022      52    M
# 501234       LORETO         MAYNAS                 IQUITOS  2022      51    M
# 501235   SAN MARTIN     SAN MARTIN    LA BANDA DE SHILCAYO  2022      47    F
#
#         edad   enfermedad       year
# 0          9  SIN_SEÑALES 2000-01-01
# 1         18  SIN_SEÑALES 2000-01-01
# 2         32  SIN_SEÑALES 2000-01-01
# 3         40  SIN_SEÑALES 2000-01-01
# 4         16  SIN_SEÑALES 2000-01-01
# ...      ...          ...        ...
# 501231    17  SIN_SEÑALES 2022-01-01
# 501232    48  SIN_SEÑALES 2022-01-01
# 501233    24  SIN_SEÑALES 2022-01-01
# 501234    26  SIN_SEÑALES 2022-01-01
# 501235    25  SIN_SEÑALES 2022-01-01
#
# [501236 rows x 9 columns]

# %%
# Let's save the current dataframe
dengueSub.to_pickle("dengueSub.pkl")

# %%
# for R
#import os

#os.environ['R_HOME'] = '/Library/Frameworks/R.framework/Resources'

from rpy2.robjects import pandas2ri
pandas2ri.activate()

from rpy2.robjects.packages import importr

base = importr('base')
base.saveRDS(dengueSub,file='dengueSub.rds')
# Out:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x15ca46a10> [0]

# %% [markdown]
# At this stage, we should aggregate the data:

# %%
CasesByWeek=dengueSub.groupby(['departamento', 'provincia', 'distrito','ano', 'semana','sexo','enfermedad']).agg({'case': ['sum']})
CasesByWeek
# Out:
#                                                                           case
#                                                                            sum
# departamento provincia  distrito   ano  semana sexo enfermedad
# AMAZONAS     BAGUA      ARAMANGO   2001 13     M    SIN_SEÑALES_DE_ALARMA    2
#                                         14     F    SIN_SEÑALES_DE_ALARMA    2
#                                         15     F    SIN_SEÑALES_DE_ALARMA    8
#                                         16     F    SIN_SEÑALES_DE_ALARMA    2
#                                                M    SIN_SEÑALES_DE_ALARMA    2
# ...                                                                        ...
# UCAYALI      PADRE ABAD PADRE ABAD 2022 52     M    CON_SEÑALES_DE_ALARMA    1
#                                                     SIN_SEÑALES_DE_ALARMA    2
#              PURUS      PURUS      2020 51     M    SIN_SEÑALES_DE_ALARMA    1
#                                    2022 28     F    CON_SEÑALES_DE_ALARMA    1
#                                         51     M    SIN_SEÑALES_DE_ALARMA    1
#
# [101993 rows x 1 columns]

# %% [markdown]
# We may turn that multi-index structure in a simpler way:

# %%
CasesByWeek.columns=['cases'] # new name for the only column

CasesByWeek.reset_index(drop=False,inplace=True)

CasesByWeek

# %% [markdown]
# ## Reshaping
#
# ### From Long to Wide
#
# The object *CasesByWeek* shows the values in one column, and the other column serve as identifier (an index). Let's make a simple wide version (one index):

# %%
CasesByWeek.pivot_table(values='cases',
                            index=['departamento'],
                            columns='enfermedad',aggfunc="sum")

# %% [markdown]
# The reshaping with two keys:

# %%
CasesByWeek.pivot_table(values='cases',
                            index=['departamento', 'provincia'],
                            columns='enfermedad',aggfunc="sum")

# %% [markdown]
# The reshaping with two keys and two multi columns:

# %%
CasesByWeek.pivot_table(values='cases',
                            index=['departamento', 'provincia'],
                            columns=['enfermedad','sexo'],aggfunc="sum")

# %% [markdown]
# Have you noticed that the more keys the more missing values?
#
# Let's keep this last one, and it in a traditional way:

# %%
CasesByWeek_Wide=CasesByWeek.pivot_table(values='cases',
                            index=['departamento', 'provincia'],
                            columns=['enfermedad','sexo'],aggfunc="sum").reset_index(drop=False)
CasesByWeek_Wide

# %% [markdown]
# We have multi index, let's flatten them:

# %%
CasesByWeek_Wide.columns

# %%
CasesByWeek_Wide.columns.name = None

# %% [markdown]
# Now, concatenate the tuples:

# %%
["_".join(pair) for pair in CasesByWeek_Wide.columns[2:]]

# %%
# create the newNames
newNames=['departamento','provincia']
newNames.extend(["_".join(pair) for pair in CasesByWeek_Wide.columns[2:]])
newNames

# %%
# renaming
CasesByWeek_Wide.columns=newNames
CasesByWeek_Wide.columns

# %% [markdown]
# We could re format the strings in the columns:

# %%
CasesByWeek_Wide.columns.str.title().str.replace('\\s','',regex=True).str.replace("Dengue","",regex=False)

# %%
# last step 
CasesByWeek_Wide.columns=CasesByWeek_Wide.columns.str.title().str.replace('\\s','',regex=True).str.replace("Dengue","",regex=False)

CasesByWeek_Wide

# %% [markdown]
# ### Wide to Long
#
# We should be able to transfor this wide version into a long one:

# %%
# maybe not this one:
CasesByWeek_Wide.set_index('Departamento').stack().reset_index()

# %%
CasesByWeek_Long=CasesByWeek_Wide.set_index(['Departamento','Provincia']).stack().reset_index()
CasesByWeek_Long

# %%
CasesByWeek_Long.rename(columns={'level_2':'status',0:'cases'},inplace=True)
CasesByWeek_Long
